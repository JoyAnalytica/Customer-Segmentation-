# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings('ignore')

# %%
customer=pd.read_csv('customer_cleaned.csv')
product=pd.read_csv('product_cleaned.csv')
sales=pd.read_csv('sales_cleaned.csv')

# %%
df = (
    sales
    .merge(customer, on='Customer_ID', how='left')
    .merge(product, on='Product_ID', how='left')
)

print(df.shape)
# Out:
# (250000, 48)

# %%
Quantity,

# %%
df['Order_Date'] = pd.to_datetime({
    'year': df['order_year'],
    'month': df['order_month'],
    'day': df['order_day']
})

# %%
snapshot_date = df['Order_Date'].max()

recency = df.groupby('Customer_ID')['Order_Date'].max().reset_index()

recency['Recency'] = (
    snapshot_date - recency['Order_Date']
).dt.days

# %%
customer_df = df.groupby('Customer_ID').agg(
    Total_Spending=('Total_Amount', 'sum'),
    Total_Orders=('Order_ID', 'nunique'),
    Avg_Order_Value=('Total_Amount', 'mean'),
    Total_Quantity=('Quantity', 'sum'),
    Avg_Discount=('Coupon_Discount', 'mean'),
    Avg_Shipping_Cost=('Shipping_Cost', 'mean')
).reset_index()

# %%
customer_df
# Out:
#         Customer_ID  Total_Spending  Total_Orders  Avg_Order_Value  \
# 0      CUST00000001        40098.48             5      8019.696000
# 1      CUST00000002        96487.46            10      9648.746000
# 2      CUST00000003        73387.76             2     36693.880000
# 3      CUST00000004       388923.23             9     43213.692222
# 4      CUST00000005        75252.85             6     12542.141667
# ...             ...             ...           ...              ...
# 39909  CUST00039996       137030.99             4     34257.747500
# 39910  CUST00039997       206692.82            10     20669.282000
# 39911  CUST00039998       203490.34             9     22610.037778
# 39912  CUST00039999        39050.69             3     13016.896667
# 39913  CUST00040000       495777.86            10     49577.786000
#
#        Total_Quantity  Avg_Discount  Avg_Shipping_Cost
# 0                   5      0.000000          17.352000
# ...

# %%
customer_df = customer_df.merge(
    recency[['Customer_ID', 'Recency']],
    on='Customer_ID',
    how='left'
)

# %%
customer_df
# Out:
#         Customer_ID  Total_Spending  Total_Orders  Avg_Order_Value  \
# 0      CUST00000001        40098.48             5      8019.696000
# 1      CUST00000002        96487.46            10      9648.746000
# 2      CUST00000003        73387.76             2     36693.880000
# 3      CUST00000004       388923.23             9     43213.692222
# 4      CUST00000005        75252.85             6     12542.141667
# ...             ...             ...           ...              ...
# 39909  CUST00039996       137030.99             4     34257.747500
# 39910  CUST00039997       206692.82            10     20669.282000
# 39911  CUST00039998       203490.34             9     22610.037778
# 39912  CUST00039999        39050.69             3     13016.896667
# 39913  CUST00040000       495777.86            10     49577.786000
#
#        Total_Quantity  Avg_Discount  Avg_Shipping_Cost  Recency
# 0                   5      0.000000          17.352000      169
# ...

# %%
customer_df.isnull().sum()
# Out:
# Customer_ID          0
# Total_Spending       0
# Total_Orders         0
# Avg_Order_Value      0
# Total_Quantity       0
# Avg_Discount         0
# Avg_Shipping_Cost    0
# Recency              0
# dtype: int64

# %%
customer_df.describe()
# Out:
#        Total_Spending  Total_Orders  Avg_Order_Value  Total_Quantity  \
# count    3.991400e+04  39914.000000     39914.000000    39914.000000
# mean     1.485868e+05      6.263466     23749.057997        7.826702
# std      1.212671e+05      2.482456     18212.000413        3.365307
# min      1.043500e+02      1.000000       104.350000        1.000000
# 25%      5.598149e+04      4.000000     10200.732875        5.000000
# 50%      1.193191e+05      6.000000     20180.200714        8.000000
# 75%      2.102680e+05      8.000000     32761.106727       10.000000
# max      1.071444e+06     19.000000    341701.770000       27.000000
#
#        Avg_Discount  Avg_Shipping_Cost       Recency
# count  39914.000000       39914.000000  39914.000000
# mean     250.432146           4.957714    119.903818
# std      619.511164           8.719653    116.502162
# min        0.000000           0.000000      0.000000
# 25%        0.000000           0.000000     34.000000
# ...

# %%
sns.boxplot(data=customer_df,x='Total_Spending')
# Out:
# <Axes: xlabel='Total_Spending'>

# %%
Q1 = customer_df['Total_Spending'].quantile(0.25)
Q3 = customer_df['Total_Spending'].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outliers = customer_df[
    (customer_df['Total_Spending'] < lower) |
    (customer_df['Total_Spending'] > upper)
]

print("Number of outliers:", len(outliers))
print("Percentage:", len(outliers) / len(customer_df) * 100)
# Out:
# Number of outliers: 1106
# Percentage: 2.770957558751315

# %%
feature=customer_df.select_dtypes(include='number')
feature.skew()
# Out:
# Total_Spending        1.335073
# Total_Orders          0.422819
# Avg_Order_Value       1.895712
# Total_Quantity        0.532445
# Avg_Discount          5.123864
# Avg_Shipping_Cost     2.332285
# Recency               1.700652
# Total_Spending_Log   -1.201936
# dtype: float64

# %%
sns.histplot(data=customer_df,x='Total_Spending')
# Out:
# <Axes: xlabel='Total_Spending', ylabel='Count'>

# %%
customer_df['Total_Spending_Log'] = np.log1p(
    customer_df['Total_Spending']
)

# %%
sns.histplot(
    data=customer_df,
    x='Total_Spending_Log'
)
# Out:
# <Axes: xlabel='Total_Spending_Log', ylabel='Count'>

# %%
customer_df.drop(columns='Total_Spending',inplace=True)

# %%
customer_df
# Out:
#         Customer_ID  Total_Orders  Avg_Order_Value  Total_Quantity  \
# 0      CUST00000001             5      8019.696000               5
# 1      CUST00000002            10      9648.746000              12
# 2      CUST00000003             2     36693.880000               3
# 3      CUST00000004             9     43213.692222               9
# 4      CUST00000005             6     12542.141667               8
# ...             ...           ...              ...             ...
# 39909  CUST00039996             4     34257.747500               4
# 39910  CUST00039997            10     20669.282000              10
# 39911  CUST00039998             9     22610.037778              11
# 39912  CUST00039999             3     13016.896667               4
# 39913  CUST00040000            10     49577.786000              12
#
#        Avg_Discount  Avg_Shipping_Cost  Recency  Total_Spending_Log
# 0          0.000000          17.352000      169           10.599119
# ...

# %%
sns.boxplot(data=customer_df,x='Avg_Discount')
# Out:
# <Axes: xlabel='Avg_Discount'>

# %%
Q1 = customer_df['Avg_Discount'].quantile(0.25)
Q3 = customer_df['Avg_Discount'].quantile(0.75)

IQR = Q3 - Q1

lower = Q1 - 1.5 * IQR
upper = Q3 + 1.5 * IQR

outliers = customer_df[
    (customer_df['Avg_Discount'] < lower) |
    (customer_df['Avg_Discount'] > upper)
]

print("Q1:", Q1)
print("Q3:", Q3)
print("IQR:", IQR)
print("Lower:", lower)
print("Upper:", upper)
print("Number of outliers:", len(outliers))
print("Percentage:", len(outliers) / len(customer_df) * 100)
# Out:
# Q1: 0.0
# Q3: 170.42624999999998
# IQR: 170.42624999999998
# Lower: -255.63937499999997
# Upper: 426.06562499999995
# Number of outliers: 6379
# Percentage: 15.981861001152478

# %%
customer_df['Avg_Discount_Log'] = np.log1p(
    customer_df['Avg_Discount']
)

# %%
sns.histplot(
    data=customer_df,
    x='Avg_Discount_Log'
)
# Out:
# <Axes: xlabel='Avg_Discount_Log', ylabel='Count'>

# %%
sns.boxplot(
    data=customer_df,
    x='Avg_Discount_Log'
)
# Out:
# <Axes: xlabel='Avg_Discount_Log'>

# %%
customer_df.drop(columns='Avg_Discount',inplace=True)

# %%
customer_df
# Out:
#         Customer_ID  Total_Orders  Avg_Order_Value  Total_Quantity  \
# 0      CUST00000001             5      8019.696000               5
# 1      CUST00000002            10      9648.746000              12
# 2      CUST00000003             2     36693.880000               3
# 3      CUST00000004             9     43213.692222               9
# 4      CUST00000005             6     12542.141667               8
# ...             ...           ...              ...             ...
# 39909  CUST00039996             4     34257.747500               4
# 39910  CUST00039997            10     20669.282000              10
# 39911  CUST00039998             9     22610.037778              11
# 39912  CUST00039999             3     13016.896667               4
# 39913  CUST00040000            10     49577.786000              12
#
#        Avg_Shipping_Cost  Recency  Total_Spending_Log  Avg_Discount_Log
# 0              17.352000      169           10.599119          0.000000
# ...

# %%
customer_df.columns
# Out:
# Index(['Customer_ID', 'Total_Orders', 'Avg_Order_Value', 'Total_Quantity',
#        'Avg_Shipping_Cost', 'Recency', 'Total_Spending_Log',
#        'Avg_Discount_Log'],
#       dtype='object')

# %%
features = [
    'Total_Orders',
    'Avg_Order_Value',
    'Total_Quantity',
    'Recency',
    'Total_Spending_Log',
    'Avg_Discount_Log'
]

X = customer_df[features].values

# %%
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
X_scaled
# Out:
# array([[-5.08964601e-01, -8.63691999e-01, -8.39964368e-01,
#          4.21423913e-01, -7.96922769e-01, -1.26843845e+00],
#        [ 1.50519494e+00, -7.74241616e-01,  1.24010977e+00,
#          1.46747457e-01, -1.09640115e-03, -2.98204242e-01],
#        [-1.71746032e+00,  7.10794195e-01, -1.43427126e+00,
#          9.40922904e-03, -2.49120412e-01, -1.26843845e+00],
#        ...,
#        [ 1.10236303e+00, -6.25430739e-02,  9.42956321e-01,
#         -7.28783746e-01,  6.75219146e-01,  1.01429239e+00],
#        [-1.31462842e+00, -5.89298019e-01, -1.13711782e+00,
#         -5.31360043e-01, -8.20920291e-01,  3.78474358e-01],
#        [ 1.50519494e+00,  1.41824352e+00,  1.24010977e+00,
#         -6.85865550e-01,  1.48232634e+00,  2.00150804e+00]],
#       shape=(39914, 6))

# %%
from sklearn.cluster import KMeans

# %%
# find the best K value

# %%
wcss=[]
for i in range (1,11):
    kmeans=KMeans(n_clusters=i,init='k-means++',random_state=42)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)

# %%
plt.plot(range(1,11),wcss)
plt.show()

# %% [markdown]
# # final model

# %%
model=KMeans(n_clusters=5,init='k-means++',random_state=42)

# %%
y_kmeans=model.fit_predict(X_scaled)

# %% [markdown]
# # visilizuation

# %%
plt.figure(figsize=(15,8))
plt.scatter(X[y_kmeans==0,0],X[y_kmeans==0,1],s=100,c='magenta',label='cluster 1')
plt.scatter(X[y_kmeans==1,0],X[y_kmeans==1,1],s=100,c='red',label='cluster 2')
plt.scatter(X[y_kmeans==2,0],X[y_kmeans==2,1],s=100,c='green',label='cluster 3')
plt.scatter(X[y_kmeans==3,0],X[y_kmeans==3,1],s=100,c='blue',label='cluster 4')
plt.scatter(X[y_kmeans==4,0],X[y_kmeans==4,1],s=100,c='yellow',label='cluster 4')
plt.scatter(kmeans.cluster_centers_[:,0],kmeans.cluster_centers_[:,1],s=200,c='black',label='centorids')
plt.legend()
plt.show()
